# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# C:\Users\maoma\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a
# WARNING:tensorflow:From <ipython-input-1-bad51c6b3b41>:177: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Initialized
# Average loss at step  0 :  273.306640625
# Nearest to known: lonergan, preachers, clemente, months, penang, cathay, sacraments, musicologist,
# Nearest to used: telford, astronomical, astronomer, fraunhofer, falklands, hooking, frankish, brainwashing,
# Nearest to from: ld, physically, stumbled, spring, lussac, nasr, uranium, recoverable,
# Nearest to than: freleng, staying, dur, kwanzaa, pandemonium, hafez, sodom, farther,
# Nearest to time: parlance, wonderswan, sidra, acceptability, conclusion, ptc, saintly, favor,
# Nearest to called: artillery, planner, expectancy, mpla, trademarked, dme, mk, deformation,
# Nearest to for: valera, mamma, activator, amalthea, development, wallpaper, albornoz, mechanistic,
# Nearest to two: socrates, provoked, lix, australes, emmerdale, nec, accordion, markov,
# Nearest to american: figured, ras, leith, kwakiutl, astrology, boxes, phrased, cabell,
# Nearest to will: mondial, heavens, garten, effort, couture, with, neuromuscular, ssr,
# Nearest to when: linguistics, congreso, sixths, confessing, micrometres, charlie, entr, physiocrats,
# Nearest to three: aliphatic, forces, matrix, cpus, nicaea, interchangeable, kurukshetra, borgir,
# Nearest to five: cruzi, iie, serbs, grimes, mortars, rf, mecca, whence,
# Nearest to may: visionary, ecclesiastic, annotations, muriel, orford, supervision, grading, develops,
# Nearest to that: generalisations, sara, randal, piccolo, doren, generators, slang, managed,
# Nearest to war: astana, cullen, landmark, alleviation, ediacaran, unsolved, armand, cma,
# Average loss at step  2000 :  114.69907002735138
# Average loss at step  4000 :  51.853294780254366
# Average loss at step  6000 :  33.09091592288017
# Average loss at step  8000 :  23.52685120177269
# Average loss at step  10000 :  17.706236440658568
# Nearest to known: coke, extradition, months, spanish, phi, alleged, vs, bottle,
# Nearest to used: vs, astronomical, degeneration, elements, astronomer, course, throne, nonexistence,
# Nearest to from: and, of, ld, in, physically, punished, to, at,
# Nearest to than: and, exclusively, is, nietzsche, in, therapists, flag, farther,
# Nearest to time: parlance, educational, favor, linebackers, geopolitics, conclusion, survives, effects,
# Nearest to called: artillery, mya, hyacinthus, agave, sanction, gb, coke, mpla,
# Nearest to for: and, of, in, with, agave, neolithic, continental, lnot,
# Nearest to two: one, nine, vs, rudolph, three, zero, papyrus, socrates,
# Nearest to american: completeness, plato, ras, astrology, popularity, termination, wayne, protected,
# Nearest to will: heavens, effort, combination, hitchcock, mathbf, alibi, desire, would,
# Nearest to when: linguistics, word, studio, plus, races, sector, way, charlie,
# Nearest to three: four, zero, six, nine, two, altenberg, aardwolf, lnot,
# Nearest to five: nine, zero, phi, vs, six, eight, one, steve,
# Nearest to may: supervision, holy, develops, prohibited, beam, skeptical, lover, discussion,
# Nearest to that: refrigerator, managed, and, which, austrian, human, chadic, ions,
# Nearest to war: landmark, frida, rs, prize, reason, nutrients, autistic, cease,
# Average loss at step  12000 :  14.234233606815339
# Average loss at step  14000 :  11.893029837846756
# Average loss at step  16000 :  10.045403666973113
# Average loss at step  18000 :  8.489989185810089
# Average loss at step  20000 :  7.927673484921455
# Nearest to known: clemente, dasyprocta, extradition, coke, months, used, agouti, alleged,
# Nearest to used: astronomical, agouti, vs, astronomer, degeneration, elements, frankish, throne,
# Nearest to from: in, and, of, at, by, to, pseudonyms, with,
# Nearest to than: exclusively, and, is, nietzsche, in, therapists, farther, gurps,
# Nearest to time: parlance, circ, educational, agouti, linebackers, conclusion, geopolitics, survives,
# Nearest to called: circ, artillery, mya, agouti, planner, gb, incompressible, hyacinthus,
# Nearest to for: in, and, of, with, as, by, to, circ,
# Nearest to two: one, three, eight, agouti, four, nine, six, zero,
# Nearest to american: and, completeness, plato, circ, ras, termination, figured, classrooms,
# Nearest to will: would, heavens, dtp, madeleine, effort, alibi, combination, syrian,
# Nearest to when: circ, and, linguistics, word, petals, abbess, agouti, plus,
# Nearest to three: two, six, nine, zero, four, eight, seven, agouti,
# Nearest to five: nine, zero, eight, six, seven, two, four, three,
# Nearest to may: would, supervision, visionary, prohibited, skeptical, beam, wave, holy,
# Nearest to that: which, and, refrigerator, managed, movements, agouti, dasyprocta, algorithmic,
# Nearest to war: landmark, frida, hbox, rs, prize, sakhalin, cullen, cease,
# Average loss at step  22000 :  7.054928735852242
# Average loss at step  24000 :  6.813747501850128
# Average loss at step  26000 :  6.681947157502174
# Average loss at step  28000 :  6.351743929624558
# Average loss at step  30000 :  5.894147739529609
# Nearest to known: clemente, used, dasyprocta, trinomial, coke, extradition, months, alleged,
# Nearest to used: astronomical, agouti, vs, known, degeneration, frontiers, throne, nonexistence,
# Nearest to from: in, by, at, for, agouti, with, of, punished,
# Nearest to than: exclusively, and, with, in, conveys, nietzsche, for, streamlining,
# Nearest to time: parlance, circ, clone, linebackers, agouti, educational, effects, geopolitics,
# Nearest to called: circ, artillery, mya, agouti, arin, gb, incompressible, expectancy,
# Nearest to for: amalthea, in, and, with, of, by, as, to,
# Nearest to two: three, four, six, one, five, agouti, eight, seven,
# Nearest to american: and, completeness, lacaille, ras, plato, doth, termination, astoria,
# Nearest to will: would, xxxx, heavens, madeleine, may, dtp, ye, alibi,
# Nearest to when: circ, and, but, in, trinomial, word, three, lynx,
# Nearest to three: four, six, two, eight, five, seven, nine, zero,
# Nearest to five: six, eight, four, zero, nine, seven, three, agouti,
# Nearest to may: would, can, xxxx, visionary, will, supervision, prohibited, should,
# Nearest to that: which, this, masking, refrigerator, agouti, dying, who, hobbyists,
# Nearest to war: landmark, frida, alleviation, rs, sakhalin, ifvs, cullen, hbox,
# Average loss at step  32000 :  5.9677811924219135
# Average loss at step  34000 :  5.638154592394828
# Average loss at step  36000 :  5.770777292490005
# Average loss at step  38000 :  5.52189039337635
# Average loss at step  40000 :  5.247679364919662
# Nearest to known: used, clemente, alleged, extradition, months, dasyprocta, trinomial, coke,
# Nearest to used: agouti, known, astronomical, vs, degeneration, aargau, frontiers, nonexistence,
# Nearest to from: in, agouti, at, by, of, zero, with, over,
# Nearest to than: or, conveys, with, exclusively, friend, gurps, exclaimed, towards,
# Nearest to time: parlance, circ, linebackers, kifl, agouti, clone, flew, educational,
# Nearest to called: circ, artillery, mya, expectancy, agouti, arin, UNK, gb,
# Nearest to for: amalthea, of, with, in, to, stitch, by, as,
# Nearest to two: three, one, four, six, five, eight, seven, zero,
# Nearest to american: and, completeness, lacaille, ras, plato, ghats, doth, classrooms,
# Nearest to will: would, xxxx, may, can, heavens, madeleine, ye, dtp,
# Nearest to when: but, circ, word, three, lynx, trinomial, in, agouti,
# Nearest to three: four, six, five, two, eight, seven, zero, one,
# Nearest to five: six, four, eight, three, seven, zero, nine, two,
# Nearest to may: would, can, will, should, amraam, xxxx, supervision, visionary,
# Nearest to that: which, this, masking, what, agouti, who, where, hobbyists,
# Nearest to war: landmark, alleviation, frida, rs, astrologers, cullen, ifvs, sakhalin,
# Average loss at step  42000 :  5.3687317892313
# Average loss at step  44000 :  5.260923400878906
# Average loss at step  46000 :  5.251515761613846
# Average loss at step  48000 :  5.2147856132984165
# Average loss at step  50000 :  5.003939813613892
# Nearest to known: used, clemente, mukherjee, alleged, dasyprocta, extradition, well, months,
# Nearest to used: known, agouti, astronomical, tatian, capacities, degeneration, frontiers, cremated,
# Nearest to from: in, for, of, by, at, agouti, among, nine,
# Nearest to than: or, conveys, friend, with, exclaimed, exclusively, gurps, for,
# Nearest to time: circ, parlance, kapoor, linebackers, geopolitics, flew, agouti, clone,
# Nearest to called: circ, artillery, agouti, expectancy, mya, gb, arin, watterson,
# Nearest to for: amalthea, in, of, with, stitch, circ, agouti, from,
# Nearest to two: three, four, one, six, five, agouti, seven, eight,
# Nearest to american: completeness, and, lacaille, operatorname, circ, doth, english, astoria,
# Nearest to will: would, xxxx, can, may, heavens, to, ye, madeleine,
# Nearest to when: but, and, circ, three, if, trinomial, as, johansen,
# Nearest to three: four, two, six, five, seven, eight, agouti, one,
# Nearest to five: six, four, eight, three, seven, agouti, zero, circ,
# Nearest to may: can, would, will, should, might, amraam, xxxx, visionary,
# Nearest to that: which, this, what, kapoor, agouti, masking, where, mukherjee,
# Nearest to war: landmark, alleviation, frida, astrologers, ifvs, rs, celeste, sakhalin,
# Average loss at step  52000 :  5.0734078351259235
# Average loss at step  54000 :  5.224360368728638
# Average loss at step  56000 :  5.033917895436287
# Average loss at step  58000 :  5.0458642963171005
# Average loss at step  60000 :  4.969414387583733
# Nearest to known: used, clemente, well, alleged, mukherjee, cumbria, such, dasyprocta,
# Nearest to used: known, agouti, microsite, astronomical, capacities, nonexistence, tatian, appear,
# Nearest to from: in, ursus, balboa, agouti, at, of, by, into,
# Nearest to than: or, friend, conveys, arctos, with, exclaimed, gurps, six,
# Nearest to time: circ, michelob, kapoor, parlance, ursus, geopolitics, clone, kifl,
# Nearest to called: circ, artillery, expectancy, mya, agouti, microsite, gb, watterson,
# Nearest to for: amalthea, of, michelob, ursus, in, to, stitch, circ,
# Nearest to two: three, four, one, six, five, agouti, ursus, operatorname,
# Nearest to american: and, completeness, lacaille, english, doth, ras, circ, operatorname,
# Nearest to will: would, can, may, xxxx, should, did, heavens, thibetanus,
# Nearest to when: if, circ, as, but, three, trinomial, johansen, while,
# Nearest to three: four, two, five, six, eight, seven, agouti, one,
# Nearest to five: six, four, eight, three, seven, nine, zero, agouti,
# Nearest to may: can, would, will, should, might, could, xxxx, amraam,
# Nearest to that: which, this, what, but, kapoor, masking, agouti, who,
# Nearest to war: landmark, alleviation, frida, prat, recompilation, streetcar, congregationalist, ifvs,
# Average loss at step  62000 :  5.026641707777977
# Average loss at step  64000 :  4.834940722167492
# Average loss at step  66000 :  4.605684509277344
# Average loss at step  68000 :  4.988843274831772
# Average loss at step  70000 :  4.8985317562818524
# Nearest to known: used, clemente, well, alleged, such, mukherjee, causality, cumbria,
# Nearest to used: known, cebus, mico, agouti, microsite, thaler, microcebus, found,
# Nearest to from: in, ursus, into, balboa, agouti, through, at, michelob,
# Nearest to than: or, conveys, friend, arctos, exclaimed, gurps, but, ppt,
# Nearest to time: mico, michelob, circ, geopolitics, kapoor, ursus, parlance, clone,
# Nearest to called: circ, expectancy, agouti, artillery, and, mya, microsite, cebus,
# Nearest to for: amalthea, leontopithecus, thaler, ursus, michelob, in, callithrix, of,
# Nearest to two: three, four, six, five, one, seven, eight, agouti,
# Nearest to american: and, completeness, lacaille, english, doth, gnawing, struggle, phrased,
# Nearest to will: would, can, may, xxxx, should, could, did, must,
# Nearest to when: if, circ, while, but, where, as, johansen, trinomial,
# Nearest to three: four, five, six, two, seven, eight, agouti, thaler,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to may: can, would, will, should, might, could, xxxx, amraam,
# Nearest to that: which, this, what, mico, microcebus, but, where, agouti,
# Nearest to war: landmark, alleviation, recompilation, streetcar, frida, prat, cebus, congregationalist,
# Average loss at step  72000 :  4.756442229747773
# Average loss at step  74000 :  4.80737876355648
# Average loss at step  76000 :  4.728960382819175
# Average loss at step  78000 :  4.809991970360279
# Average loss at step  80000 :  4.804604173183441
# Nearest to known: used, clemente, such, well, alleged, recognized, mukherjee, cumbria,
# Nearest to used: known, cebus, found, mico, agouti, microsite, thaler, microcebus,
# Nearest to from: in, through, into, ursus, balboa, of, by, at,
# Nearest to than: or, conveys, friend, witwatersrand, freleng, arctos, but, gurps,
# Nearest to time: mico, circ, michelob, kapoor, ursus, linebackers, geopolitics, microcebus,
# Nearest to called: circ, agouti, cebus, expectancy, artillery, mya, arin, microsite,
# Nearest to for: amalthea, thaler, ursus, of, michelob, stitch, callithrix, agouti,
# Nearest to two: three, four, six, five, one, seven, agouti, ursus,
# Nearest to american: english, completeness, british, lacaille, doth, superiority, gnawing, and,
# Nearest to will: would, can, may, xxxx, should, could, must, to,
# Nearest to when: if, circ, while, but, where, trinomial, however, during,
# Nearest to three: four, six, five, two, seven, eight, agouti, thaler,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to may: can, would, will, should, might, could, xxxx, must,
# Nearest to that: which, this, what, mico, microcebus, however, but, kapoor,
# Nearest to war: landmark, alleviation, streetcar, frida, ifvs, recompilation, congregationalist, bridges,
# Average loss at step  82000 :  4.752692797064781
# Average loss at step  84000 :  4.752980633735657
# Average loss at step  86000 :  4.76063347697258
# Average loss at step  88000 :  4.760321665644645
# Average loss at step  90000 :  4.7409799175262455
# Nearest to known: used, clemente, such, well, alleged, recognized, cumbria, seen,
# Nearest to used: known, cebus, found, mico, agouti, microsite, thaler, microcebus,
# Nearest to from: in, ursus, balboa, into, through, agouti, at, michelob,
# Nearest to than: or, conveys, friend, witwatersrand, but, arctos, freleng, gurps,
# Nearest to time: mico, geopolitics, michelob, ursus, circ, kapoor, linebackers, clone,
# Nearest to called: circ, UNK, and, agouti, cebus, expectancy, mya, arin,
# Nearest to for: amalthea, thaler, leontopithecus, ursus, in, including, callithrix, stitch,
# Nearest to two: three, four, one, five, six, seven, eight, agouti,
# Nearest to american: english, british, completeness, lacaille, struggle, doth, superiority, phrased,
# Nearest to will: would, can, may, could, should, xxxx, must, did,
# Nearest to when: if, while, where, after, during, circ, however, but,
# Nearest to three: four, five, six, two, seven, eight, one, agouti,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to may: can, would, will, might, should, could, must, did,
# Nearest to that: which, what, this, however, but, microcebus, where, mico,
# Nearest to war: landmark, congregationalist, streetcar, ifvs, recompilation, alleviation, cebus, frida,
# Average loss at step  92000 :  4.672876571297645
# Average loss at step  94000 :  4.716458131074905
# Average loss at step  96000 :  4.688895608067512
# Average loss at step  98000 :  4.602028457760811
# Average loss at step  100000 :  4.687823728561401
# Nearest to known: used, such, clemente, well, alleged, recognized, seen, dasyprocta,
# Nearest to used: known, cebus, found, mico, agouti, microsite, microcebus, thaler,
# Nearest to from: in, through, into, ursus, balboa, agouti, at, under,
# Nearest to than: or, conveys, friend, freleng, arctos, witwatersrand, gurps, dorchester,
# Nearest to time: mico, ursus, michelob, circ, geopolitics, kapoor, clone, parlance,
# Nearest to called: circ, and, agouti, cebus, expectancy, artillery, microsite, struck,
# Nearest to for: amalthea, thaler, leontopithecus, ursus, of, michelob, stitch, callithrix,
# Nearest to two: three, four, five, six, one, seven, eight, ursus,
# Nearest to american: english, british, lacaille, struggle, superiority, doth, astoria, shen,
# Nearest to will: would, can, may, could, should, must, xxxx, did,
# Nearest to when: if, while, after, where, during, circ, trinomial, as,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to may: can, would, will, should, might, could, must, did,
# Nearest to that: which, what, however, this, but, microcebus, mico, agouti,
# Nearest to war: landmark, streetcar, congregationalist, cebus, conjunction, alleviation, bridges, odessa,
